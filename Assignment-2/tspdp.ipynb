# %%
pip install gymnasium
# Out:
# Collecting gymnasium
#   Downloading gymnasium-0.29.1-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (1.26.4)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (2.2.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.10/dist-packages (from gymnasium) (4.12.2)
# Collecting farama-notifications>=0.0.1 (from gymnasium)
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl.metadata (558 bytes)
# Downloading gymnasium-0.29.1-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.9/953.9 kB 12.3 MB/s eta 0:00:00
# Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Installing collected packages: farama-notifications, gymnasium
# Successfully installed farama-notifications-0.0.4 gymnasium-0.29.1

# %%
import numpy as np
from typing import Dict, List, Optional, Tuple
import gymnasium as gym


class TSP(gym.Env):
    """Traveling Salesman Problem (TSP) RL environment."""

    def __init__(self, num_targets: int, max_area: int = 30, seed: int = None) -> None:
        """Initialize the environment by generating random target locations."""
        super().__init__()
        if seed is not None:
            np.random.seed(seed=seed)
        self.num_targets = num_targets
        self.max_area = max_area
        self.locations = self._generate_points(num_targets)
        self.distances = self._calculate_distances(self.locations)
        self.visited = None
        self.current_location = None
        self.steps = 0

    def _generate_points(self, num_points: int) -> np.ndarray:
        """Generate random 2D coordinates for each target."""
        points = []
        while len(points) < num_points:
            x = np.random.random() * self.max_area
            y = np.random.random() * self.max_area
            points.append([x, y])
        return np.array(points)

    def _calculate_distances(self, locations: List) -> np.ndarray:
        """Compute pairwise distances between all target locations."""
        n = len(locations)
        distances = np.zeros((n, n))
        for i in range(n):
            for j in range(n):
                distances[i, j] = np.linalg.norm(locations[i] - locations[j])
        return distances

    def reset(self) -> Tuple[np.ndarray, dict]:
        """Reset the environment by setting the agent at the starting location and resetting visits."""
        self.steps = 0
        self.current_location = 0  # Start at the first location
        self.visited = [False] * self.num_targets
        self.visited[self.current_location] = True
        state = (self.current_location, tuple(self.visited))
        return state, {}

    def step(self, action: int) -> Tuple[np.ndarray, float, bool, bool, dict]:
        """Move to the selected target (action)."""
        if self.visited[action]:
            return (self.current_location, tuple(self.visited)), -10000, True, False, {}

        reward = -self.distances[self.current_location, action]
        self.visited[action] = True
        self.current_location = action
        self.steps += 1

        # Check if all targets have been visited
        done = all(self.visited)
        return (self.current_location, tuple(self.visited)), reward, done, False, {}


def value_iteration(env: TSP, gamma=1.0, max_iterations=1000, tolerance=1e-6):
    """Run Value Iteration to solve the TSP."""
    n = env.num_targets
    state_space_size = (n, 1 << n)  # State space: num_targets * 2^num_targets
    value_function = np.zeros(state_space_size)
    policy = np.zeros(state_space_size, dtype=int)

    for iteration in range(max_iterations):
        delta = 0

        for loc in range(n):
            for visited_set in range(1 << n):
                if (visited_set & (1 << loc)) == 0:  # Skipping invalid states
                    continue

                best_value = float('inf')
                best_action = -1

                # Check all possible next locations
                for next_loc in range(n):
                    if visited_set & (1 << next_loc):  # Skipping already visited locations
                        continue

                    next_visited_set = visited_set | (1 << next_loc)
                    reward = -env.distances[loc, next_loc]
                    value = reward + gamma * value_function[next_loc, next_visited_set]

                    if value < best_value:
                        best_value = value
                        best_action = next_loc

                if best_action != -1:
                    delta = max(delta, abs(value_function[loc, visited_set] - best_value))
                    value_function[loc, visited_set] = best_value
                    policy[loc, visited_set] = best_action

        # If the change in value is smaller than tolerance, exit early
        if delta < tolerance:
            print(f"Value Iteration converged after {iteration} iterations.")
            break

    return value_function, policy


def extract_policy(env: TSP, policy: np.ndarray) -> List[int]:
    """Extract the optimal path based on the policy."""
    current_city = 0
    visited_set = 1  # Start at city 0 (marked as visited)
    path = [current_city]

    while len(path) < env.num_targets:
        next_city = policy[current_city, visited_set]
        path.append(int(next_city))  # Adding the next city to the path
        visited_set |= (1 << next_city)  # Marking the next city as visited
        current_city = next_city

    return path


if __name__ == "__main__":
    # Initializing environment with 10 targets
    num_targets = 10
    env = TSP(num_targets)

    # Running value iteration
    value_function, policy = value_iteration(env)

    # Extracting and display the optimal path
    optimal_path = extract_policy(env, policy)
    print(f"Optimal Path (Visiting Order): {optimal_path}")

    # Displaying state values and policy decisions after convergence
    print("\nOptimal State Values and Policy Decisions:")
    for loc in range(num_targets):
        for visited_set in range(1 << num_targets):
            if (visited_set & (1 << loc)) != 0:  # Only show valid states
                state_value = value_function[loc, visited_set]
                next_city = policy[loc, visited_set]
                visited_set_str = bin(visited_set)[2:].zfill(num_targets)
                print(f"From City {loc} with Visited {visited_set_str}: Value={state_value:.4f}, "
                      f"Next City={next_city}")
# Out:
# Streaming output truncated to the last 5000 lines.
# From City 0 with Visited 0011110001: Value=-92.7195, Next City=3
# From City 0 with Visited 0011110011: Value=-78.7163, Next City=3
# From City 0 with Visited 0011110101: Value=-74.6954, Next City=1
# From City 0 with Visited 0011110111: Value=-56.1268, Next City=3
# From City 0 with Visited 0011111001: Value=-68.4654, Next City=1
# From City 0 with Visited 0011111011: Value=-48.4509, Next City=2
# From City 0 with Visited 0011111101: Value=-45.8759, Next City=1
# From City 0 with Visited 0011111111: Value=-18.8649, Next City=8
# From City 0 with Visited 0100000001: Value=-166.3476, Next City=2
# From City 0 with Visited 0100000011: Value=-132.5246, Next City=2
# From City 0 with Visited 0100000101: Value=-140.1280, Next City=3
# From City 0 with Visited 0100000111: Value=-105.6470, Next City=3
# From City 0 with Visited 0100001001: Value=-132.4521, Next City=2
# From City 0 with Visited 0100001011: Value=-97.9710, Next City=2
# From City 0 with Visited 0100001101: Value=-102.8242, Next City=7
# From City 0 with Visited 0100001111: Value=-70.3692, Next City=7
# From City 0 with Visited 0100010001: Value=-149.6417, Next City=3
# From City 0 with Visited 0100010011: Value=-129.0537, Next City=2
# From City 0 with Visited 0100010101: Value=-134.9726, Next City=3
# From City 0 with Visited 0100010111: Value=-101.6685, Next City=3
# From City 0 with Visited 0100011001: Value=-127.2967, Next City=2
# From City 0 with Visited 0100011011: Value=-93.9926, Next City=2
# From City 0 with Visited 0100011101: Value=-96.6431, Next City=5
# From City 0 with Visited 0100011111: Value=-65.1861, Next City=6
# From City 0 with Visited 0100100001: Value=-126.8285, Next City=2
# From City 0 with Visited 0100100011: Value=-91.2494, Next City=2
# From City 0 with Visited 0100100101: Value=-99.9509, Next City=3
# From City 0 with Visited 0100100111: Value=-65.2531, Next City=7
# From City 0 with Visited 0100101001: Value=-92.2750, Next City=2
# From City 0 with Visited 0100101011: Value=-56.1440, Next City=7
# From City 0 with Visited 0100101101: Value=-63.8240, Next City=7
# From City 0 with Visited 0100101111: Value=-30.1920, Next City=7
# From City 0 with Visited 0100110001: Value=-123.3576, Next City=2
# From City 0 with Visited 0100110011: Value=-87.2710, Next City=2
# From City 0 with Visited 0100110101: Value=-95.9725, Next City=3
# From City 0 with Visited 0100110111: Value=-61.2471, Next City=6
# From City 0 with Visited 0100111001: Value=-88.2965, Next City=2
# From City 0 with Visited 0100111011: Value=-52.1380, Next City=6
# From City 0 with Visited 0100111101: Value=-57.5657, Next City=7
# From City 0 with Visited 0100111111: Value=-26.1860, Next City=6
# From City 0 with Visited 0101000001: Value=-142.7679, Next City=3
# From City 0 with Visited 0101000011: Value=-123.4847, Next City=2
# From City 0 with Visited 0101000101: Value=-127.9399, Next City=3
# From City 0 with Visited 0101000111: Value=-97.2651, Next City=3
# From City 0 with Visited 0101001001: Value=-120.2639, Next City=2
# From City 0 with Visited 0101001011: Value=-89.5892, Next City=2
# From City 0 with Visited 0101001101: Value=-91.3322, Next City=5
# From City 0 with Visited 0101001111: Value=-60.8103, Next City=7
# From City 0 with Visited 0101010001: Value=-126.1079, Next City=3
# From City 0 with Visited 0101010011: Value=-106.7788, Next City=3
# From City 0 with Visited 0101010101: Value=-110.9189, Next City=3
# From City 0 with Visited 0101010111: Value=-92.1097, Next City=3
# From City 0 with Visited 0101011001: Value=-103.2430, Next City=2
# From City 0 with Visited 0101011011: Value=-84.4338, Next City=2
# From City 0 with Visited 0101011101: Value=-84.4826, Next City=5
# From City 0 with Visited 0101011111: Value=-55.5020, Next City=5
# From City 0 with Visited 0101100001: Value=-116.8811, Next City=2
# From City 0 with Visited 0101100011: Value=-84.3630, Next City=2
# From City 0 with Visited 0101100101: Value=-90.6615, Next City=3
# From City 0 with Visited 0101100111: Value=-58.3666, Next City=7
# From City 0 with Visited 0101101001: Value=-82.9856, Next City=2
# From City 0 with Visited 0101101011: Value=-50.0317, Next City=7
# From City 0 with Visited 0101101101: Value=-51.6634, Next City=7
# From City 0 with Visited 0101101111: Value=-22.1810, Next City=7
# From City 0 with Visited 0101110001: Value=-100.1867, Next City=3
# From City 0 with Visited 0101110011: Value=-80.8921, Next City=2
# From City 0 with Visited 0101110101: Value=-83.8119, Next City=3
# From City 0 with Visited 0101110111: Value=-54.8314, Next City=3
# From City 0 with Visited 0101111001: Value=-76.1360, Next City=2
# From City 0 with Visited 0101111011: Value=-47.1554, Next City=2
# From City 0 with Visited 0101111101: Value=-45.4051, Next City=7
# From City 0 with Visited 0101111111: Value=-16.4246, Next City=7
# From City 0 with Visited 0110000001: Value=-148.0125, Next City=3
# From City 0 with Visited 0110000011: Value=-128.1146, Next City=2
# From City 0 with Visited 0110000101: Value=-133.1845, Next City=3
# From City 0 with Visited 0110000111: Value=-100.7294, Next City=3
# From City 0 with Visited 0110001001: Value=-125.5085, Next City=2
# From City 0 with Visited 0110001011: Value=-93.0535, Next City=2
# From City 0 with Visited 0110001101: Value=-94.8550, Next City=5
# From City 0 with Visited 0110001111: Value=-62.8961, Next City=6
# From City 0 with Visited 0110010001: Value=-131.3525, Next City=3
# From City 0 with Visited 0110010011: Value=-111.5676, Next City=3
# From City 0 with Visited 0110010101: Value=-116.1635, Next City=3
# From City 0 with Visited 0110010111: Value=-94.7028, Next City=3
# From City 0 with Visited 0110011001: Value=-108.4875, Next City=2
# From City 0 with Visited 0110011011: Value=-87.0269, Next City=2
# From City 0 with Visited 0110011101: Value=-87.7751, Next City=5
# From City 0 with Visited 0110011111: Value=-57.1396, Next City=6
# From City 0 with Visited 0110100001: Value=-121.5694, Next City=2
# From City 0 with Visited 0110100011: Value=-87.9375, Next City=2
# From City 0 with Visited 0110100101: Value=-94.1843, Next City=3
# From City 0 with Visited 0110100111: Value=-60.5523, Next City=3
# From City 0 with Visited 0110101001: Value=-86.5084, Next City=2
# From City 0 with Visited 0110101011: Value=-52.8764, Next City=2
# From City 0 with Visited 0110101101: Value=-54.6567, Next City=6
# From City 0 with Visited 0110101111: Value=-23.8959, Next City=6
# From City 0 with Visited 0110110001: Value=-104.5485, Next City=2
# From City 0 with Visited 0110110011: Value=-83.0878, Next City=2
# From City 0 with Visited 0110110101: Value=-86.4634, Next City=3
# From City 0 with Visited 0110110111: Value=-55.7026, Next City=3
# From City 0 with Visited 0110111001: Value=-78.7875, Next City=2
# From City 0 with Visited 0110111011: Value=-48.0267, Next City=2
# From City 0 with Visited 0110111101: Value=-48.9003, Next City=6
# From City 0 with Visited 0110111111: Value=-18.1395, Next City=6
# From City 0 with Visited 0111000001: Value=-123.3806, Next City=3
# From City 0 with Visited 0111000011: Value=-105.9987, Next City=3
# From City 0 with Visited 0111000101: Value=-108.1916, Next City=3
# From City 0 with Visited 0111000111: Value=-91.1706, Next City=3
# From City 0 with Visited 0111001001: Value=-100.5157, Next City=2
# From City 0 with Visited 0111001011: Value=-83.4947, Next City=2
# From City 0 with Visited 0111001101: Value=-82.6944, Next City=5
# From City 0 with Visited 0111001111: Value=-53.2120, Next City=5
# From City 0 with Visited 0111010001: Value=-99.6327, Next City=5
# From City 0 with Visited 0111010011: Value=-83.0160, Next City=3
# From City 0 with Visited 0111010101: Value=-84.4437, Next City=5
# From City 0 with Visited 0111010111: Value=-70.7144, Next City=5
# From City 0 with Visited 0111011001: Value=-82.0482, Next City=5
# From City 0 with Visited 0111011011: Value=-66.8592, Next City=5
# From City 0 with Visited 0111011101: Value=-65.6734, Next City=5
# From City 0 with Visited 0111011111: Value=-47.4555, Next City=5
# From City 0 with Visited 0111100001: Value=-98.3986, Next City=3
# From City 0 with Visited 0111100011: Value=-81.0510, Next City=2
# From City 0 with Visited 0111100101: Value=-82.0237, Next City=3
# From City 0 with Visited 0111100111: Value=-52.5413, Next City=3
# From City 0 with Visited 0111101001: Value=-74.3478, Next City=2
# From City 0 with Visited 0111101011: Value=-44.8654, Next City=2
# From City 0 with Visited 0111101101: Value=-42.2904, Next City=1
# From City 0 with Visited 0111101111: Value=-11.8467, Next City=4
# From City 0 with Visited 0111110001: Value=-81.3776, Next City=3
# From City 0 with Visited 0111110011: Value=-66.1885, Next City=3
# From City 0 with Visited 0111110101: Value=-65.0027, Next City=3
# From City 0 with Visited 0111110111: Value=-46.7848, Next City=3
# From City 0 with Visited 0111111001: Value=-57.3268, Next City=2
# From City 0 with Visited 0111111011: Value=-39.1089, Next City=2
# From City 0 with Visited 0111111101: Value=-36.5340, Next City=1
# From City 0 with Visited 0111111111: Value=-0.3348, Next City=9
# From City 0 with Visited 1000000001: Value=-154.0781, Next City=3
# From City 0 with Visited 1000000011: Value=-129.2318, Next City=2
# From City 0 with Visited 1000000101: Value=-137.0742, Next City=3
# From City 0 with Visited 1000000111: Value=-108.9541, Next City=3
# From City 0 with Visited 1000001001: Value=-128.7736, Next City=2
# From City 0 with Visited 1000001011: Value=-100.6535, Next City=2
# From City 0 with Visited 1000001101: Value=-105.7032, Next City=5
# From City 0 with Visited 1000001111: Value=-75.1229, Next City=7
# From City 0 with Visited 1000010001: Value=-137.1937, Next City=3
# From City 0 with Visited 1000010011: Value=-116.2555, Next City=3
# From City 0 with Visited 1000010101: Value=-121.7932, Next City=5
# From City 0 with Visited 1000010111: Value=-100.1659, Next City=3
# From City 0 with Visited 1000011001: Value=-114.4100, Next City=5
# From City 0 with Visited 1000011011: Value=-91.3367, Next City=2
# From City 0 with Visited 1000011101: Value=-97.9347, Next City=5
# From City 0 with Visited 1000011111: Value=-69.8146, Next City=5
# From City 0 with Visited 1000100001: Value=-123.5357, Next City=2
# From City 0 with Visited 1000100011: Value=-95.0300, Next City=2
# From City 0 with Visited 1000100101: Value=-102.4090, Next City=3
# From City 0 with Visited 1000100111: Value=-69.4994, Next City=7
# From City 0 with Visited 1000101001: Value=-94.1084, Next City=2
# From City 0 with Visited 1000101011: Value=-60.4764, Next City=2
# From City 0 with Visited 1000101101: Value=-68.5778, Next City=7
# From City 0 with Visited 1000101111: Value=-34.9458, Next City=7
# From City 0 with Visited 1000110001: Value=-110.5594, Next City=3
# From City 0 with Visited 1000110011: Value=-84.6151, Next City=2
# From City 0 with Visited 1000110101: Value=-94.4698, Next City=3
# From City 0 with Visited 1000110111: Value=-65.9641, Next City=3
# From City 0 with Visited 1000111001: Value=-85.6407, Next City=2
# From City 0 with Visited 1000111011: Value=-56.8894, Next City=2
# From City 0 with Visited 1000111101: Value=-61.9425, Next City=8
# From City 0 with Visited 1000111111: Value=-30.9398, Next City=6
# From City 0 with Visited 1001000001: Value=-131.1689, Next City=3
# From City 0 with Visited 1001000011: Value=-111.2152, Next City=3
# From City 0 with Visited 1001000101: Value=-114.9194, Next City=5
# From City 0 with Visited 1001000111: Value=-94.2113, Next City=3
# From City 0 with Visited 1001001001: Value=-108.0648, Next City=5
# From City 0 with Visited 1001001011: Value=-85.9107, Next City=2
# From City 0 with Visited 1001001101: Value=-89.9629, Next City=5
# From City 0 with Visited 1001001111: Value=-62.5987, Next City=5
# From City 0 with Visited 1001010001: Value=-108.4096, Next City=3
# From City 0 with Visited 1001010011: Value=-91.4581, Next City=5
# From City 0 with Visited 1001010101: Value=-93.2206, Next City=3
# From City 0 with Visited 1001010111: Value=-78.9303, Next City=5
# From City 0 with Visited 1001011001: Value=-92.0294, Next City=5
# From City 0 with Visited 1001011011: Value=-71.5471, Next City=5
# From City 0 with Visited 1001011101: Value=-73.8448, Next City=5
# From City 0 with Visited 1001011111: Value=-55.0718, Next City=5
# From City 0 with Visited 1001100001: Value=-104.6116, Next City=3
# From City 0 with Visited 1001100011: Value=-80.6845, Next City=2
# From City 0 with Visited 1001100101: Value=-87.6077, Next City=3
# From City 0 with Visited 1001100111: Value=-59.3045, Next City=3
# From City 0 with Visited 1001101001: Value=-79.3071, Next City=2
# From City 0 with Visited 1001101011: Value=-51.0039, Next City=2
# From City 0 with Visited 1001101101: Value=-54.9214, Next City=8
# From City 0 with Visited 1001101111: Value=-25.4733, Next City=7
# From City 0 with Visited 1001110001: Value=-88.5762, Next City=3
# From City 0 with Visited 1001110011: Value=-68.0939, Next City=3
# From City 0 with Visited 1001110101: Value=-70.5521, Next City=1
# From City 0 with Visited 1001110111: Value=-51.6186, Next City=3
# From City 0 with Visited 1001111001: Value=-63.2718, Next City=2
# From City 0 with Visited 1001111011: Value=-42.7895, Next City=2
# From City 0 with Visited 1001111101: Value=-46.6936, Next City=1
# From City 0 with Visited 1001111111: Value=-19.0913, Next City=8
# From City 0 with Visited 1010000001: Value=-136.4135, Next City=3
# From City 0 with Visited 1010000011: Value=-116.0040, Next City=3
# From City 0 with Visited 1010000101: Value=-120.1640, Next City=5
# From City 0 with Visited 1010000111: Value=-99.3858, Next City=3
# From City 0 with Visited 1010001001: Value=-113.3094, Next City=5
# From City 0 with Visited 1010001011: Value=-91.0852, Next City=2
# From City 0 with Visited 1010001101: Value=-95.1958, Next City=5
# From City 0 with Visited 1010001111: Value=-67.7732, Next City=5
# From City 0 with Visited 1010010001: Value=-113.6542, Next City=3
# From City 0 with Visited 1010010011: Value=-96.2469, Next City=5
# From City 0 with Visited 1010010101: Value=-98.4652, Next City=3
# From City 0 with Visited 1010010111: Value=-83.7191, Next City=5
# From City 0 with Visited 1010011001: Value=-97.2740, Next City=5
# From City 0 with Visited 1010011011: Value=-76.0904, Next City=5
# From City 0 with Visited 1010011101: Value=-79.0894, Next City=5
# From City 0 with Visited 1010011111: Value=-60.2463, Next City=5
# From City 0 with Visited 1010100001: Value=-109.4588, Next City=3
# From City 0 with Visited 1010100011: Value=-85.4616, Next City=2
# From City 0 with Visited 1010100101: Value=-92.8406, Next City=3
# From City 0 with Visited 1010100111: Value=-63.9227, Next City=3
# From City 0 with Visited 1010101001: Value=-84.5400, Next City=2
# From City 0 with Visited 1010101011: Value=-54.8480, Next City=2
# From City 0 with Visited 1010101101: Value=-60.1543, Next City=8
# From City 0 with Visited 1010101111: Value=-28.8983, Next City=6
# From City 0 with Visited 1010110001: Value=-93.4235, Next City=3
# From City 0 with Visited 1010110011: Value=-72.2398, Next City=3
# From City 0 with Visited 1010110101: Value=-75.3993, Next City=1
# From City 0 with Visited 1010110111: Value=-56.3957, Next City=3
# From City 0 with Visited 1010111001: Value=-68.5047, Next City=2
# From City 0 with Visited 1010111011: Value=-47.3210, Next City=2
# From City 0 with Visited 1010111101: Value=-51.9265, Next City=1
# From City 0 with Visited 1010111111: Value=-21.6727, Next City=8
# From City 0 with Visited 1011000001: Value=-105.8670, Next City=5
# From City 0 with Visited 1011000011: Value=-90.6779, Next City=5
# From City 0 with Visited 1011000101: Value=-90.4934, Next City=3
# From City 0 with Visited 1011000111: Value=-78.1502, Next City=5
# From City 0 with Visited 1011001001: Value=-89.3021, Next City=5
# From City 0 with Visited 1011001011: Value=-71.2955, Next City=5
# From City 0 with Visited 1011001101: Value=-71.1175, Next City=5
# From City 0 with Visited 1011001111: Value=-52.0913, Next City=5
# From City 0 with Visited 1011010001: Value=-81.9344, Next City=5
# From City 0 with Visited 1011010011: Value=-65.3178, Next City=3
# From City 0 with Visited 1011010101: Value=-66.7454, Next City=5
# From City 0 with Visited 1011010111: Value=-53.0161, Next City=5
# From City 0 with Visited 1011011001: Value=-65.8303, Next City=5
# From City 0 with Visited 1011011011: Value=-50.6413, Next City=5
# From City 0 with Visited 1011011101: Value=-47.6457, Next City=5
# From City 0 with Visited 1011011111: Value=-38.1135, Next City=5
# From City 0 with Visited 1011100001: Value=-86.9470, Next City=3
# From City 0 with Visited 1011100011: Value=-68.9404, Next City=3
# From City 0 with Visited 1011100101: Value=-68.9229, Next City=1
# From City 0 with Visited 1011100111: Value=-49.7362, Next City=3
# From City 0 with Visited 1011101001: Value=-62.0682, Next City=1
# From City 0 with Visited 1011101011: Value=-41.4356, Next City=2
# From City 0 with Visited 1011101101: Value=-42.8640, Next City=1
# From City 0 with Visited 1011101111: Value=-17.0499, Next City=8
# From City 0 with Visited 1011110001: Value=-66.1454, Next City=3
# From City 0 with Visited 1011110011: Value=-50.9563, Next City=3
# From City 0 with Visited 1011110101: Value=-47.9607, Next City=3
# From City 0 with Visited 1011110111: Value=-38.4286, Next City=3
# From City 0 with Visited 1011111001: Value=-46.0329, Next City=1
# From City 0 with Visited 1011111011: Value=-32.2330, Next City=2
# From City 0 with Visited 1011111101: Value=-27.8482, Next City=1
# From City 0 with Visited 1011111111: Value=-9.5229, Next City=8
# From City 0 with Visited 1100000001: Value=-141.5503, Next City=3
# From City 0 with Visited 1100000011: Value=-119.2778, Next City=2
# From City 0 with Visited 1100000101: Value=-127.5059, Next City=3
# From City 0 with Visited 1100000111: Value=-93.7472, Next City=7
# From City 0 with Visited 1100001001: Value=-119.2053, Next City=2
# From City 0 with Visited 1100001011: Value=-84.7242, Next City=2
# From City 0 with Visited 1100001101: Value=-93.6747, Next City=7
# From City 0 with Visited 1100001111: Value=-59.1936, Next City=7
# From City 0 with Visited 1100010001: Value=-124.6659, Next City=3
# From City 0 with Visited 1100010011: Value=-103.7278, Next City=3
# From City 0 with Visited 1100010101: Value=-109.4769, Next City=3
# From City 0 with Visited 1100010111: Value=-90.2119, Next City=3
# From City 0 with Visited 1100011001: Value=-102.3208, Next City=2
# From City 0 with Visited 1100011011: Value=-81.1372, Next City=2
# From City 0 with Visited 1100011101: Value=-88.3664, Next City=5
# From City 0 with Visited 1100011111: Value=-55.1876, Next City=6
# From City 0 with Visited 1100100001: Value=-113.5817, Next City=2
# From City 0 with Visited 1100100011: Value=-78.0026, Next City=2
# From City 0 with Visited 1100100101: Value=-88.0511, Next City=7
# From City 0 with Visited 1100100111: Value=-52.4720, Next City=7
# From City 0 with Visited 1100101001: Value=-79.0282, Next City=2
# From City 0 with Visited 1100101011: Value=-42.7576, Next City=2
# From City 0 with Visited 1100101101: Value=-53.4976, Next City=7
# From City 0 with Visited 1100101111: Value=-16.8080, Next City=6
# From City 0 with Visited 1100110001: Value=-98.0317, Next City=3
# From City 0 with Visited 1100110011: Value=-74.4156, Next City=2
# From City 0 with Visited 1100110101: Value=-84.5158, Next City=3
# From City 0 with Visited 1100110111: Value=-48.4660, Next City=6
# From City 0 with Visited 1100111001: Value=-75.4411, Next City=2
# From City 0 with Visited 1100111011: Value=-38.2036, Next City=6
# From City 0 with Visited 1100111101: Value=-49.4915, Next City=6
# From City 0 with Visited 1100111111: Value=-11.8874, Next City=6
# From City 0 with Visited 1101000001: Value=-118.6411, Next City=3
# From City 0 with Visited 1101000011: Value=-98.6874, Next City=3
# From City 0 with Visited 1101000101: Value=-103.4521, Next City=3
# From City 0 with Visited 1101000111: Value=-84.6430, Next City=3
# From City 0 with Visited 1101001001: Value=-96.1372, Next City=2
# From City 0 with Visited 1101001011: Value=-76.3424, Next City=2
# From City 0 with Visited 1101001101: Value=-81.3336, Next City=5
# From City 0 with Visited 1101001111: Value=-50.8118, Next City=7
# From City 0 with Visited 1101010001: Value=-92.9461, Next City=5
# From City 0 with Visited 1101010011: Value=-76.3294, Next City=3
# From City 0 with Visited 1101010101: Value=-78.0419, Next City=5
# From City 0 with Visited 1101010111: Value=-64.0278, Next City=5
# From City 0 with Visited 1101011001: Value=-79.5017, Next City=5
# From City 0 with Visited 1101011011: Value=-59.0193, Next City=5
# From City 0 with Visited 1101011101: Value=-64.3126, Next City=5
# From City 0 with Visited 1101011111: Value=-45.5035, Next City=5
# From City 0 with Visited 1101100001: Value=-92.0838, Next City=3
# From City 0 with Visited 1101100011: Value=-71.1162, Next City=2
# From City 0 with Visited 1101100101: Value=-78.0394, Next City=3
# From City 0 with Visited 1101100111: Value=-45.5856, Next City=7
# From City 0 with Visited 1101101001: Value=-69.7388, Next City=2
# From City 0 with Visited 1101101011: Value=-36.6453, Next City=2
# From City 0 with Visited 1101101101: Value=-44.2082, Next City=7
# From City 0 with Visited 1101101111: Value=-11.1147, Next City=7
# From City 0 with Visited 1101110001: Value=-76.0485, Next City=3
# From City 0 with Visited 1101110011: Value=-55.5662, Next City=3
# From City 0 with Visited 1101110101: Value=-60.8594, Next City=3
# From City 0 with Visited 1101110111: Value=-42.0503, Next City=3
# From City 0 with Visited 1101111001: Value=-53.7034, Next City=2
# From City 0 with Visited 1101111011: Value=-33.2211, Next City=2
# From City 0 with Visited 1101111101: Value=-37.1252, Next City=1
# From City 0 with Visited 1101111111: Value=-8.3780, Next City=7
# From City 0 with Visited 1110000001: Value=-123.8857, Next City=3
# From City 0 with Visited 1110000011: Value=-103.4762, Next City=3
# From City 0 with Visited 1110000101: Value=-108.6967, Next City=3
# From City 0 with Visited 1110000111: Value=-89.2728, Next City=3
# From City 0 with Visited 1110001001: Value=-101.3818, Next City=2
# From City 0 with Visited 1110001011: Value=-80.1981, Next City=2
# From City 0 with Visited 1110001101: Value=-86.5782, Next City=5
# From City 0 with Visited 1110001111: Value=-54.2485, Next City=6
# From City 0 with Visited 1110010001: Value=-97.7349, Next City=5
# From City 0 with Visited 1110010011: Value=-81.1182, Next City=3
# From City 0 with Visited 1110010101: Value=-83.2865, Next City=5
# From City 0 with Visited 1110010111: Value=-68.8165, Next City=5
# From City 0 with Visited 1110011001: Value=-84.7462, Next City=5
# From City 0 with Visited 1110011011: Value=-63.5626, Next City=5
# From City 0 with Visited 1110011101: Value=-69.5572, Next City=5
# From City 0 with Visited 1110011111: Value=-48.0965, Next City=5
# From City 0 with Visited 1110100001: Value=-96.9311, Next City=3
# From City 0 with Visited 1110100011: Value=-74.5746, Next City=2
# From City 0 with Visited 1110100101: Value=-82.7277, Next City=3
# From City 0 with Visited 1110100111: Value=-49.0957, Next City=3
# From City 0 with Visited 1110101001: Value=-73.6530, Next City=2
# From City 0 with Visited 1110101011: Value=-40.0210, Next City=2
# From City 0 with Visited 1110101101: Value=-47.7034, Next City=6
# From City 0 with Visited 1110101111: Value=-14.0714, Next City=6
# From City 0 with Visited 1110110001: Value=-80.8957, Next City=3
# From City 0 with Visited 1110110011: Value=-59.7121, Next City=3
# From City 0 with Visited 1110110101: Value=-65.7067, Next City=3
# From City 0 with Visited 1110110111: Value=-44.2460, Next City=3
# From City 0 with Visited 1110111001: Value=-56.6320, Next City=2
# From City 0 with Visited 1110111011: Value=-35.1713, Next City=2
# From City 0 with Visited 1110111101: Value=-39.7767, Next City=1
# From City 0 with Visited 1110111111: Value=-9.2217, Next City=6
# From City 0 with Visited 1111000001: Value=-92.1659, Next City=5
# From City 0 with Visited 1111000011: Value=-75.5493, Next City=3
# From City 0 with Visited 1111000101: Value=-76.9769, Next City=5
# From City 0 with Visited 1111000111: Value=-63.2476, Next City=5
# From City 0 with Visited 1111001001: Value=-76.7744, Next City=5
# From City 0 with Visited 1111001011: Value=-58.7678, Next City=5
# From City 0 with Visited 1111001101: Value=-61.5854, Next City=5
# From City 0 with Visited 1111001111: Value=-44.5644, Next City=5
# From City 0 with Visited 1111010001: Value=-65.3281, Next City=5
# From City 0 with Visited 1111010011: Value=-44.5907, Next City=3
# From City 0 with Visited 1111010101: Value=-46.0183, Next City=5
# From City 0 with Visited 1111010111: Value=-32.2890, Next City=5
# From City 0 with Visited 1111011001: Value=-51.5988, Next City=5
# From City 0 with Visited 1111011011: Value=-36.4098, Next City=5
# From City 0 with Visited 1111011101: Value=-31.5692, Next City=5
# From City 0 with Visited 1111011111: Value=-23.8171, Next City=5
# From City 0 with Visited 1111100001: Value=-74.4193, Next City=3
# From City 0 with Visited 1111100011: Value=-56.4126, Next City=3
# From City 0 with Visited 1111100101: Value=-59.2302, Next City=3
# From City 0 with Visited 1111100111: Value=-42.2092, Next City=3
# From City 0 with Visited 1111101001: Value=-51.9153, Next City=2
# From City 0 with Visited 1111101011: Value=-33.9087, Next City=2
# From City 0 with Visited 1111101101: Value=-35.3371, Next City=1
# From City 0 with Visited 1111101111: Value=-6.0903, Next City=4
# From City 0 with Visited 1111110001: Value=-52.4443, Next City=3
# From City 0 with Visited 1111110011: Value=-29.2288, Next City=3
# From City 0 with Visited 1111110101: Value=-37.2553, Next City=3
# From City 0 with Visited 1111110111: Value=-23.5260, Next City=3
# From City 0 with Visited 1111111001: Value=-34.8943, Next City=2
# From City 0 with Visited 1111111011: Value=-19.7052, Next City=2
# From City 0 with Visited 1111111101: Value=-18.3161, Next City=1
# From City 0 with Visited 1111111111: Value=0.0000, Next City=0
# From City 1 with Visited 0000000010: Value=-169.8218, Next City=6
# From City 1 with Visited 0000000011: Value=-151.4461, Next City=6
# From City 1 with Visited 0000000110: Value=-142.7274, Next City=6
# From City 1 with Visited 0000000111: Value=-130.4457, Next City=6
# From City 1 with Visited 0000001010: Value=-135.0515, Next City=6
# From City 1 with Visited 0000001011: Value=-122.1107, Next City=6
# From City 1 with Visited 0000001110: Value=-104.7710, Next City=6
# From City 1 with Visited 0000001111: Value=-95.6111, Next City=6
# From City 1 with Visited 0000010010: Value=-160.1062, Next City=6
# From City 1 with Visited 0000010011: Value=-141.1412, Next City=6
# From City 1 with Visited 0000010110: Value=-135.4671, Next City=6
# From City 1 with Visited 0000010111: Value=-120.7301, Next City=6
# From City 1 with Visited 0000011010: Value=-127.7911, Next City=6
# From City 1 with Visited 0000011011: Value=-111.8665, Next City=6
# From City 1 with Visited 0000011110: Value=-99.0123, Next City=6
# From City 1 with Visited 0000011111: Value=-88.5036, Next City=6
# From City 1 with Visited 0000100010: Value=-132.6078, Next City=6
# From City 1 with Visited 0000100011: Value=-118.5690, Next City=6
# From City 1 with Visited 0000100110: Value=-104.1004, Next City=6
# From City 1 with Visited 0000100111: Value=-93.1674, Next City=6
# From City 1 with Visited 0000101010: Value=-96.4244, Next City=6
# From City 1 with Visited 0000101011: Value=-84.8324, Next City=6
# From City 1 with Visited 0000101110: Value=-65.4672, Next City=6
# From City 1 with Visited 0000101111: Value=-56.9817, Next City=6
# From City 1 with Visited 0000110010: Value=-124.3380, Next City=6
# From City 1 with Visited 0000110011: Value=-107.9274, Next City=6
# From City 1 with Visited 0000110110: Value=-98.3416, Next City=6
# From City 1 with Visited 0000110111: Value=-84.9619, Next City=6
# From City 1 with Visited 0000111010: Value=-90.6657, Next City=6
# From City 1 with Visited 0000111011: Value=-76.0983, Next City=6
# From City 1 with Visited 0000111110: Value=-59.5579, Next City=6
# From City 1 with Visited 0000111111: Value=-51.2253, Next City=6
# From City 1 with Visited 0001000010: Value=-153.2324, Next City=4
# From City 1 with Visited 0001000011: Value=-135.1164, Next City=7
# From City 1 with Visited 0001000110: Value=-129.0711, Next City=7
# From City 1 with Visited 0001000111: Value=-113.8563, Next City=4
# From City 1 with Visited 0001001010: Value=-121.3951, Next City=7
# From City 1 with Visited 0001001011: Value=-105.5213, Next City=4
# From City 1 with Visited 0001001110: Value=-91.5116, Next City=7
# From City 1 with Visited 0001001111: Value=-82.1053, Next City=7
# From City 1 with Visited 0001010010: Value=-143.1519, Next City=7
# From City 1 with Visited 0001010011: Value=-114.8232, Next City=7
# From City 1 with Visited 0001010110: Value=-120.4418, Next City=7
# From City 1 with Visited 0001010111: Value=-102.2954, Next City=7
# From City 1 with Visited 0001011010: Value=-112.7659, Next City=7
# From City 1 with Visited 0001011011: Value=-96.0655, Next City=7
# From City 1 with Visited 0001011110: Value=-85.3560, Next City=7
# From City 1 with Visited 0001011111: Value=-73.4760, Next City=7
# From City 1 with Visited 0001100010: Value=-119.0376, Next City=7
# From City 1 with Visited 0001100011: Value=-102.2510, Next City=7
# From City 1 with Visited 0001100110: Value=-90.8409, Next City=7
# From City 1 with Visited 0001100111: Value=-79.6616, Next City=7
# From City 1 with Visited 0001101010: Value=-83.1650, Next City=7
# From City 1 with Visited 0001101011: Value=-71.3266, Next City=7
# From City 1 with Visited 0001101110: Value=-51.8108, Next City=7
# From City 1 with Visited 0001101111: Value=-43.7246, Next City=7
# From City 1 with Visited 0001110010: Value=-109.3103, Next City=7
# From City 1 with Visited 0001110011: Value=-92.5237, Next City=7
# From City 1 with Visited 0001110110: Value=-84.6853, Next City=7
# From City 1 with Visited 0001110111: Value=-69.9343, Next City=7
# From City 1 with Visited 0001111010: Value=-77.0094, Next City=7
# From City 1 with Visited 0001111011: Value=-61.0707, Next City=7
# From City 1 with Visited 0001111110: Value=-46.0521, Next City=7
# From City 1 with Visited 0001111111: Value=-37.7195, Next City=7
# From City 1 with Visited 0010000010: Value=-158.4068, Next City=4
# From City 1 with Visited 0010000011: Value=-140.3610, Next City=6
# From City 1 with Visited 0010000110: Value=-134.3040, Next City=6
# From City 1 with Visited 0010000111: Value=-119.0307, Next City=4
# From City 1 with Visited 0010001010: Value=-126.6280, Next City=6
# From City 1 with Visited 0010001011: Value=-110.6958, Next City=4
# From City 1 with Visited 0010001110: Value=-96.4981, Next City=6
# From City 1 with Visited 0010001111: Value=-87.3382, Next City=6
# From City 1 with Visited 0010010010: Value=-148.3965, Next City=6
# From City 1 with Visited 0010010011: Value=-120.0678, Next City=6
# From City 1 with Visited 0010010110: Value=-125.6864, Next City=6
# From City 1 with Visited 0010010111: Value=-107.5400, Next City=6
# From City 1 with Visited 0010011010: Value=-118.0105, Next City=6
# From City 1 with Visited 0010011011: Value=-101.3101, Next City=6
# From City 1 with Visited 0010011110: Value=-90.5889, Next City=6
# From City 1 with Visited 0010011111: Value=-78.7206, Next City=6
# From City 1 with Visited 0010100010: Value=-124.2705, Next City=6
# From City 1 with Visited 0010100011: Value=-107.4839, Next City=6
# From City 1 with Visited 0010100110: Value=-95.8275, Next City=6
# From City 1 with Visited 0010100111: Value=-84.8945, Next City=6
# From City 1 with Visited 0010101010: Value=-88.1516, Next City=6
# From City 1 with Visited 0010101011: Value=-76.5595, Next City=6
# From City 1 with Visited 0010101110: Value=-55.3336, Next City=6
# From City 1 with Visited 0010101111: Value=-48.7088, Next City=6
# From City 1 with Visited 0010110010: Value=-114.1576, Next City=6
# From City 1 with Visited 0010110011: Value=-97.3710, Next City=6
# From City 1 with Visited 0010110110: Value=-89.9182, Next City=6
# From City 1 with Visited 0010110111: Value=-74.7815, Next City=6
# From City 1 with Visited 0010111010: Value=-82.2423, Next City=6
# From City 1 with Visited 0010111011: Value=-65.6724, Next City=6
# From City 1 with Visited 0010111110: Value=-49.5473, Next City=6
# From City 1 with Visited 0010111111: Value=-42.9524, Next City=6
# From City 1 with Visited 0011000010: Value=-140.4246, Next City=4
# From City 1 with Visited 0011000011: Value=-112.5643, Next City=2
# From City 1 with Visited 0011000110: Value=-117.7145, Next City=4
# From City 1 with Visited 0011000111: Value=-99.5682, Next City=4
# From City 1 with Visited 0011001010: Value=-110.0386, Next City=4
# From City 1 with Visited 0011001011: Value=-93.3382, Next City=4
# From City 1 with Visited 0011001110: Value=-82.7233, Next City=9
# From City 1 with Visited 0011001111: Value=-70.7488, Next City=4
# From City 1 with Visited 0011010010: Value=-120.5112, Next City=2
# From City 1 with Visited 0011010011: Value=-89.5816, Next City=2
# From City 1 with Visited 0011010110: Value=-104.1020, Next City=9
# From City 1 with Visited 0011010111: Value=-74.9231, Next City=3
# From City 1 with Visited 0011011010: Value=-97.9064, Next City=9
# From City 1 with Visited 0011011011: Value=-72.5277, Next City=2
# From City 1 with Visited 0011011110: Value=-75.1963, Next City=9
# From City 1 with Visited 0011011111: Value=-56.1528, Next City=9
# From City 1 with Visited 0011100010: Value=-107.6811, Next City=4
# From City 1 with Visited 0011100011: Value=-90.8945, Next City=4
# From City 1 with Visited 0011100110: Value=-82.0526, Next City=9
# From City 1 with Visited 0011100111: Value=-68.3050, Next City=4
# From City 1 with Visited 0011101010: Value=-74.3767, Next City=9
# From City 1 with Visited 0011101011: Value=-59.9701, Next City=4
# From City 1 with Visited 0011101110: Value=-43.1731, Next City=9
# From City 1 with Visited 0011101111: Value=-35.0868, Next City=9
# From City 1 with Visited 0011110010: Value=-97.2357, Next City=9
# From City 1 with Visited 0011110011: Value=-72.7541, Next City=2
# From City 1 with Visited 0011110110: Value=-74.5257, Next City=9
# From City 1 with Visited 0011110111: Value=-56.3793, Next City=9
# From City 1 with Visited 0011111010: Value=-66.8498, Next City=9
# From City 1 with Visited 0011111011: Value=-50.1493, Next City=9
# From City 1 with Visited 0011111110: Value=-37.1810, Next City=0
# From City 1 with Visited 0011111111: Value=-27.5599, Next City=9
# From City 1 with Visited 0100000010: Value=-156.8556, Next City=6
# From City 1 with Visited 0100000011: Value=-142.8168, Next City=6
# From City 1 with Visited 0100000110: Value=-128.3482, Next City=6
# From City 1 with Visited 0100000111: Value=-117.4152, Next City=6
# From City 1 with Visited 0100001010: Value=-120.6723, Next City=6
# From City 1 with Visited 0100001011: Value=-109.0802, Next City=6
# From City 1 with Visited 0100001110: Value=-91.8934, Next City=6
# From City 1 with Visited 0100001111: Value=-81.2295, Next City=6
# From City 1 with Visited 0100010010: Value=-150.5378, Next City=6
# From City 1 with Visited 0100010011: Value=-128.6134, Next City=6
# From City 1 with Visited 0100010110: Value=-124.5415, Next City=6
# From City 1 with Visited 0100010111: Value=-111.1618, Next City=6
# From City 1 with Visited 0100011010: Value=-116.8656, Next City=6
# From City 1 with Visited 0100011011: Value=-102.2982, Next City=6
# From City 1 with Visited 0100011110: Value=-86.2120, Next City=6
# From City 1 with Visited 0100011111: Value=-77.4251, Next City=6
# From City 1 with Visited 0100100010: Value=-115.7727, Next City=6
# From City 1 with Visited 0100100011: Value=-102.5175, Next City=6
# From City 1 with Visited 0100100110: Value=-89.0490, Next City=6
# From City 1 with Visited 0100100111: Value=-76.2990, Next City=6
# From City 1 with Visited 0100101010: Value=-80.7140, Next City=6
# From City 1 with Visited 0100101011: Value=-67.9640, Next City=6
# From City 1 with Visited 0100101110: Value=-52.8933, Next City=6
# From City 1 with Visited 0100101111: Value=-41.1616, Next City=6
# From City 1 with Visited 0100110010: Value=-112.9265, Next City=6
# From City 1 with Visited 0100110011: Value=-98.3591, Next City=6
# From City 1 with Visited 0100110110: Value=-85.5414, Next City=6
# From City 1 with Visited 0100110111: Value=-73.4860, Next City=6
# From City 1 with Visited 0100111010: Value=-77.8654, Next City=6
# From City 1 with Visited 0100111011: Value=-64.3769, Next City=6
# From City 1 with Visited 0100111110: Value=-47.1069, Next City=6
# From City 1 with Visited 0100111111: Value=-38.4250, Next City=6
# From City 1 with Visited 0101000010: Value=-145.4522, Next City=7
# From City 1 with Visited 0101000011: Value=-122.5886, Next City=7
# From City 1 with Visited 0101000110: Value=-118.3578, Next City=7
# From City 1 with Visited 0101000111: Value=-106.0761, Next City=7
# From City 1 with Visited 0101001010: Value=-110.6819, Next City=7
# From City 1 with Visited 0101001011: Value=-97.7411, Next City=7
# From City 1 with Visited 0101001110: Value=-80.4014, Next City=7
# From City 1 with Visited 0101001111: Value=-71.2414, Next City=7
# From City 1 with Visited 0101010010: Value=-130.6241, Next City=7
# From City 1 with Visited 0101010011: Value=-98.4419, Next City=2
# From City 1 with Visited 0101010110: Value=-111.0975, Next City=7
# From City 1 with Visited 0101010111: Value=-87.3929, Next City=7
# From City 1 with Visited 0101011010: Value=-103.4215, Next City=7
# From City 1 with Visited 0101011011: Value=-83.5377, Next City=7
# From City 1 with Visited 0101011110: Value=-74.6427, Next City=7
# From City 1 with Visited 0101011111: Value=-64.1340, Next City=7
# From City 1 with Visited 0101100010: Value=-108.2382, Next City=7
# From City 1 with Visited 0101100011: Value=-94.1994, Next City=7
# From City 1 with Visited 0101100110: Value=-79.7308, Next City=7
# From City 1 with Visited 0101100111: Value=-68.7977, Next City=7
# From City 1 with Visited 0101101010: Value=-72.0548, Next City=7
# From City 1 with Visited 0101101011: Value=-60.4628, Next City=7
# From City 1 with Visited 0101101110: Value=-40.7327, Next City=9
# From City 1 with Visited 0101101111: Value=-32.6121, Next City=7
# From City 1 with Visited 0101110010: Value=-99.9684, Next City=7
# From City 1 with Visited 0101110011: Value=-79.9960, Next City=7
# From City 1 with Visited 0101110110: Value=-73.9720, Next City=7
# From City 1 with Visited 0101110111: Value=-60.5923, Next City=7
# From City 1 with Visited 0101111010: Value=-66.2961, Next City=7
# From City 1 with Visited 0101111011: Value=-51.7287, Next City=7
# From City 1 with Visited 0101111110: Value=-34.7406, Next City=0
# From City 1 with Visited 0101111111: Value=-26.8557, Next City=7
# From City 1 with Visited 0110000010: Value=-150.6968, Next City=6
# From City 1 with Visited 0110000011: Value=-127.8332, Next City=6
# From City 1 with Visited 0110000110: Value=-122.2537, Next City=6
# From City 1 with Visited 0110000111: Value=-111.3207, Next City=6
# From City 1 with Visited 0110001010: Value=-114.5778, Next City=6
# From City 1 with Visited 0110001011: Value=-102.9857, Next City=6
# From City 1 with Visited 0110001110: Value=-83.9242, Next City=6
# From City 1 with Visited 0110001111: Value=-75.1351, Next City=6
# From City 1 with Visited 0110010010: Value=-135.8687, Next City=6
# From City 1 with Visited 0110010011: Value=-103.2307, Next City=2
# From City 1 with Visited 0110010110: Value=-116.3421, Next City=6
# From City 1 with Visited 0110010111: Value=-92.6375, Next City=6
# From City 1 with Visited 0110011010: Value=-108.6661, Next City=6
# From City 1 with Visited 0110011011: Value=-88.7823, Next City=6
# From City 1 with Visited 0110011110: Value=-78.1379, Next City=6
# From City 1 with Visited 0110011111: Value=-69.3786, Next City=6
# From City 1 with Visited 0110100010: Value=-111.7334, Next City=6
# From City 1 with Visited 0110100011: Value=-99.0466, Next City=6
# From City 1 with Visited 0110100110: Value=-83.2536, Next City=6
# From City 1 with Visited 0110100111: Value=-72.3205, Next City=6
# From City 1 with Visited 0110101010: Value=-75.5776, Next City=6
# From City 1 with Visited 0110101011: Value=-63.9856, Next City=6
# From City 1 with Visited 0110101110: Value=-42.5291, Next City=6
# From City 1 with Visited 0110101111: Value=-36.1349, Next City=6
# From City 1 with Visited 0110110010: Value=-104.8156, Next City=6
# From City 1 with Visited 0110110011: Value=-84.8432, Next City=6
# From City 1 with Visited 0110110110: Value=-77.4672, Next City=6
# From City 1 with Visited 0110110111: Value=-65.4395, Next City=6
# From City 1 with Visited 0110111010: Value=-69.7913, Next City=6
# From City 1 with Visited 0110111011: Value=-56.3304, Next City=6
# From City 1 with Visited 0110111110: Value=-36.4555, Next City=0
# From City 1 with Visited 0110111111: Value=-30.3785, Next City=6
# From City 1 with Visited 0111000010: Value=-127.8968, Next City=4
# From City 1 with Visited 0111000011: Value=-97.6617, Next City=2
# From City 1 with Visited 0111000110: Value=-109.5671, Next City=9
# From City 1 with Visited 0111000111: Value=-84.6656, Next City=4
# From City 1 with Visited 0111001010: Value=-101.8912, Next City=9
# From City 1 with Visited 0111001011: Value=-80.8105, Next City=4
# From City 1 with Visited 0111001110: Value=-71.7637, Next City=9
# From City 1 with Visited 0111001111: Value=-62.6037, Next City=9
# From City 1 with Visited 0111010010: Value=-105.6086, Next City=2
# From City 1 with Visited 0111010011: Value=-74.6791, Next City=2
# From City 1 with Visited 0111010110: Value=-89.1994, Next City=9
# From City 1 with Visited 0111010111: Value=-60.6266, Next City=3
# From City 1 with Visited 0111011010: Value=-85.3786, Next City=9
# From City 1 with Visited 0111011011: Value=-58.2312, Next City=2
# From City 1 with Visited 0111011110: Value=-65.7716, Next City=0
# From City 1 with Visited 0111011111: Value=-41.8564, Next City=9
# From City 1 with Visited 0111100010: Value=-99.5360, Next City=9
# From City 1 with Visited 0111100011: Value=-78.3668, Next City=4
# From City 1 with Visited 0111100110: Value=-71.0930, Next City=9
# From City 1 with Visited 0111100111: Value=-60.1600, Next City=9
# From City 1 with Visited 0111101010: Value=-63.4171, Next City=9
# From City 1 with Visited 0111101011: Value=-51.8250, Next City=9
# From City 1 with Visited 0111101110: Value=-30.1628, Next City=0
# From City 1 with Visited 0111101111: Value=-23.9743, Next City=9
# From City 1 with Visited 0111110010: Value=-84.7080, Next City=9
# From City 1 with Visited 0111110011: Value=-57.8516, Next City=2
# From City 1 with Visited 0111110110: Value=-65.1009, Next City=0
# From City 1 with Visited 0111110111: Value=-41.4767, Next City=9
# From City 1 with Visited 0111111010: Value=-57.4250, Next City=0
# From City 1 with Visited 0111111011: Value=-37.6216, Next City=9
# From City 1 with Visited 0111111110: Value=-18.6508, Next City=0
# From City 1 with Visited 0111111111: Value=-18.2179, Next City=9
# From City 1 with Visited 1000000010: Value=-152.0148, Next City=6
# From City 1 with Visited 1000000011: Value=-131.3653, Next City=6
# From City 1 with Visited 1000000110: Value=-130.8915, Next City=6
# From City 1 with Visited 1000000111: Value=-113.2634, Next City=6
# From City 1 with Visited 1000001010: Value=-122.5909, Next City=6
# From City 1 with Visited 1000001011: Value=-103.7751, Next City=6
# From City 1 with Visited 1000001110: Value=-96.1212, Next City=6
# From City 1 with Visited 1000001111: Value=-85.6125, Next City=6
# From City 1 with Visited 1000010010: Value=-141.7099, Next City=6
# From City 1 with Visited 1000010011: Value=-113.3812, Next City=6
# From City 1 with Visited 1000010110: Value=-121.1759, Next City=6
# From City 1 with Visited 1000010111: Value=-100.8534, Next City=6
# From City 1 with Visited 1000011010: Value=-112.3467, Next City=6
# From City 1 with Visited 1000011011: Value=-93.4702, Next City=6
# From City 1 with Visited 1000011110: Value=-88.6822, Next City=6
# From City 1 with Visited 1000011111: Value=-76.9949, Next City=6
# From City 1 with Visited 1000100010: Value=-119.1377, Next City=6
# From City 1 with Visited 1000100011: Value=-98.1516, Next City=6
# From City 1 with Visited 1000100110: Value=-93.7660, Next City=6
# From City 1 with Visited 1000100111: Value=-80.3863, Next City=6
# From City 1 with Visited 1000101010: Value=-85.4655, Next City=6
# From City 1 with Visited 1000101011: Value=-70.8980, Next City=6
# From City 1 with Visited 1000101110: Value=-57.6471, Next City=6
# From City 1 with Visited 1000101111: Value=-45.9154, Next City=6
# From City 1 with Visited 1000110010: Value=-108.4961, Next City=6
# From City 1 with Visited 1000110011: Value=-86.7486, Next City=6
# From City 1 with Visited 1000110110: Value=-85.2290, Next City=6
# From City 1 with Visited 1000110111: Value=-70.2733, Next City=6
# From City 1 with Visited 1000111010: Value=-76.3999, Next City=6
# From City 1 with Visited 1000111011: Value=-60.0110, Next City=6
# From City 1 with Visited 1000111110: Value=-51.5568, Next City=6
# From City 1 with Visited 1000111111: Value=-43.1788, Next City=6
# From City 1 with Visited 1001000010: Value=-135.6851, Next City=7
# From City 1 with Visited 1001000011: Value=-107.3564, Next City=7
# From City 1 with Visited 1001000110: Value=-114.3020, Next City=4
# From City 1 with Visited 1001000111: Value=-94.8287, Next City=7
# From City 1 with Visited 1001001010: Value=-106.0015, Next City=4
# From City 1 with Visited 1001001011: Value=-87.9741, Next City=7
# From City 1 with Visited 1001001110: Value=-82.4648, Next City=7
# From City 1 with Visited 1001001111: Value=-69.0231, Next City=4
# From City 1 with Visited 1001010010: Value=-115.2689, Next City=7
# From City 1 with Visited 1001010011: Value=-82.8950, Next City=2
# From City 1 with Visited 1001010110: Value=-102.7412, Next City=7
# From City 1 with Visited 1001010111: Value=-69.6946, Next City=7
# From City 1 with Visited 1001011010: Value=-96.5456, Next City=7
# From City 1 with Visited 1001011011: Value=-67.3198, Next City=7
# From City 1 with Visited 1001011110: Value=-73.8356, Next City=7
# From City 1 with Visited 1001011111: Value=-54.7921, Next City=7
# From City 1 with Visited 1001100010: Value=-102.8197, Next City=7
# From City 1 with Visited 1001100011: Value=-82.7478, Next City=7
# From City 1 with Visited 1001100110: Value=-80.1097, Next City=7
# From City 1 with Visited 1001100111: Value=-63.7969, Next City=4
# From City 1 with Visited 1001101010: Value=-71.8091, Next City=7
# From City 1 with Visited 1001101011: Value=-55.1087, Next City=7
# From City 1 with Visited 1001101110: Value=-44.2371, Next City=7
# From City 1 with Visited 1001101111: Value=-35.9044, Next City=7
# From City 1 with Visited 1001110010: Value=-93.0924, Next City=7
# From City 1 with Visited 1001110011: Value=-64.7638, Next City=7
# From City 1 with Visited 1001110110: Value=-70.3824, Next City=7
# From City 1 with Visited 1001110111: Value=-52.2360, Next City=7
# From City 1 with Visited 1001111010: Value=-61.5532, Next City=7
# From City 1 with Visited 1001111011: Value=-44.8528, Next City=7
# From City 1 with Visited 1001111110: Value=-37.9004, Next City=7
# From City 1 with Visited 1001111111: Value=-28.3775, Next City=7
# From City 1 with Visited 1010000010: Value=-140.9297, Next City=6
# From City 1 with Visited 1010000011: Value=-112.6010, Next City=6
# From City 1 with Visited 1010000110: Value=-119.4765, Next City=4
# From City 1 with Visited 1010000111: Value=-100.0733, Next City=6
# From City 1 with Visited 1010001010: Value=-111.1759, Next City=4
# From City 1 with Visited 1010001011: Value=-93.2186, Next City=6
# From City 1 with Visited 1010001110: Value=-87.6977, Next City=6
# From City 1 with Visited 1010001111: Value=-74.1975, Next City=4
# From City 1 with Visited 1010010010: Value=-120.5135, Next City=6
# From City 1 with Visited 1010010011: Value=-87.6838, Next City=2
# From City 1 with Visited 1010010110: Value=-107.9858, Next City=6
# From City 1 with Visited 1010010111: Value=-74.9392, Next City=6
# From City 1 with Visited 1010011010: Value=-101.7902, Next City=6
# From City 1 with Visited 1010011011: Value=-72.5644, Next City=6
# From City 1 with Visited 1010011110: Value=-79.0801, Next City=6
# From City 1 with Visited 1010011111: Value=-60.0366, Next City=6
# From City 1 with Visited 1010100010: Value=-108.0526, Next City=6
# From City 1 with Visited 1010100011: Value=-87.5951, Next City=6
# From City 1 with Visited 1010100110: Value=-85.3426, Next City=6
# From City 1 with Visited 1010100111: Value=-68.5740, Next City=4
# From City 1 with Visited 1010101010: Value=-77.0420, Next City=6
# From City 1 with Visited 1010101011: Value=-60.3416, Next City=6
# ...
# From City 9 with Visited 1100001011: Value=-84.4227, Next City=2
# From City 9 with Visited 1100001100: Value=-103.0028, Next City=7
# From City 9 with Visited 1100001101: Value=-93.3431, Next City=7
# From City 9 with Visited 1100001110: Value=-70.6730, Next City=7
# From City 9 with Visited 1100001111: Value=-58.8621, Next City=7
# From City 9 with Visited 1100010000: Value=-149.9433, Next City=5
# From City 9 with Visited 1100010001: Value=-124.3987, Next City=3
# From City 9 with Visited 1100010010: Value=-129.3208, Next City=2
# From City 9 with Visited 1100010011: Value=-103.4606, Next City=3
# From City 9 with Visited 1100010100: Value=-135.1512, Next City=3
# From City 9 with Visited 1100010101: Value=-109.2097, Next City=3
# From City 9 with Visited 1100010110: Value=-101.9724, Next City=3
# From City 9 with Visited 1100010111: Value=-89.9448, Next City=3
# From City 9 with Visited 1100011000: Value=-127.4753, Next City=2
# From City 9 with Visited 1100011001: Value=-102.0193, Next City=2
# From City 9 with Visited 1100011010: Value=-94.2965, Next City=2
# From City 9 with Visited 1100011011: Value=-80.8357, Next City=2
# From City 9 with Visited 1100011100: Value=-96.9470, Next City=5
# From City 9 with Visited 1100011101: Value=-88.1878, Next City=5
# From City 9 with Visited 1100011110: Value=-65.5177, Next City=5
# From City 9 with Visited 1100011111: Value=-54.8837, Next City=6
# From City 9 with Visited 1100100000: Value=-127.1600, Next City=2
# From City 9 with Visited 1100100001: Value=-113.2802, Next City=2
# From City 9 with Visited 1100100010: Value=-91.5810, Next City=2
# From City 9 with Visited 1100100011: Value=-77.7011, Next City=2
# From City 9 with Visited 1100100100: Value=-100.2824, Next City=3
# From City 9 with Visited 1100100101: Value=-87.7196, Next City=7
# From City 9 with Visited 1100100110: Value=-65.5203, Next City=7
# From City 9 with Visited 1100100111: Value=-52.1405, Next City=7
# From City 9 with Visited 1100101000: Value=-92.6065, Next City=2
# From City 9 with Visited 1100101001: Value=-78.7266, Next City=2
# From City 9 with Visited 1100101010: Value=-56.4456, Next City=7
# From City 9 with Visited 1100101011: Value=-42.4561, Next City=2
# From City 9 with Visited 1100101100: Value=-64.1279, Next City=7
# From City 9 with Visited 1100101101: Value=-53.1660, Next City=7
# From City 9 with Visited 1100101110: Value=-30.4959, Next City=7
# From City 9 with Visited 1100101111: Value=-16.5041, Next City=6
# From City 9 with Visited 1100110000: Value=-123.6248, Next City=2
# From City 9 with Visited 1100110001: Value=-97.7645, Next City=3
# From City 9 with Visited 1100110010: Value=-87.5749, Next City=2
# From City 9 with Visited 1100110011: Value=-74.1141, Next City=2
# From City 9 with Visited 1100110100: Value=-96.2764, Next City=3
# From City 9 with Visited 1100110101: Value=-84.2487, Next City=3
# From City 9 with Visited 1100110110: Value=-61.5786, Next City=3
# From City 9 with Visited 1100110111: Value=-48.1621, Next City=6
# From City 9 with Visited 1100111000: Value=-88.6004, Next City=2
# From City 9 with Visited 1100111001: Value=-75.1396, Next City=2
# From City 9 with Visited 1100111010: Value=-52.4695, Next City=2
# From City 9 with Visited 1100111011: Value=-37.8997, Next City=6
# From City 9 with Visited 1100111100: Value=-57.5657, Next City=6
# From City 9 with Visited 1100111101: Value=-49.1876, Next City=6
# From City 9 with Visited 1100111110: Value=-26.5175, Next City=6
# From City 9 with Visited 1100111111: Value=-11.5835, Next City=6
# From City 9 with Visited 1101000000: Value=-143.0695, Next City=5
# From City 9 with Visited 1101000001: Value=-118.3740, Next City=3
# From City 9 with Visited 1101000010: Value=-123.7519, Next City=2
# From City 9 with Visited 1101000011: Value=-98.4203, Next City=3
# From City 9 with Visited 1101000100: Value=-128.1184, Next City=3
# From City 9 with Visited 1101000101: Value=-103.1850, Next City=3
# From City 9 with Visited 1101000110: Value=-97.5966, Next City=3
# From City 9 with Visited 1101000111: Value=-84.3758, Next City=3
# From City 9 with Visited 1101001000: Value=-120.4425, Next City=2
# From City 9 with Visited 1101001001: Value=-95.8356, Next City=2
# From City 9 with Visited 1101001010: Value=-89.9207, Next City=2
# From City 9 with Visited 1101001011: Value=-76.0408, Next City=2
# From City 9 with Visited 1101001100: Value=-91.6637, Next City=5
# From City 9 with Visited 1101001101: Value=-81.1550, Next City=5
# From City 9 with Visited 1101001110: Value=-60.9889, Next City=7
# From City 9 with Visited 1101001111: Value=-50.4802, Next City=7
# From City 9 with Visited 1101010000: Value=-126.2865, Next City=3
# From City 9 with Visited 1101010001: Value=-92.7675, Next City=5
# From City 9 with Visited 1101010010: Value=-107.0804, Next City=5
# From City 9 with Visited 1101010011: Value=-76.0623, Next City=3
# From City 9 with Visited 1101010100: Value=-111.0975, Next City=3
# From City 9 with Visited 1101010101: Value=-77.8633, Next City=5
# From City 9 with Visited 1101010110: Value=-92.2883, Next City=3
# From City 9 with Visited 1101010111: Value=-63.8492, Next City=5
# From City 9 with Visited 1101011000: Value=-103.4215, Next City=2
# From City 9 with Visited 1101011001: Value=-79.3231, Next City=5
# From City 9 with Visited 1101011010: Value=-84.6124, Next City=2
# From City 9 with Visited 1101011011: Value=-58.8407, Next City=5
# From City 9 with Visited 1101011100: Value=-84.5807, Next City=5
# From City 9 with Visited 1101011101: Value=-64.1340, Next City=5
# From City 9 with Visited 1101011110: Value=-55.8336, Next City=5
# From City 9 with Visited 1101011111: Value=-45.3249, Next City=5
# From City 9 with Visited 1101100000: Value=-117.1483, Next City=2
# From City 9 with Visited 1101100001: Value=-91.8167, Next City=3
# From City 9 with Visited 1101100010: Value=-84.6945, Next City=2
# From City 9 with Visited 1101100011: Value=-70.8146, Next City=2
# From City 9 with Visited 1101100100: Value=-90.9930, Next City=3
# From City 9 with Visited 1101100101: Value=-77.7722, Next City=3
# From City 9 with Visited 1101100110: Value=-58.6338, Next City=7
# From City 9 with Visited 1101100111: Value=-45.2540, Next City=7
# From City 9 with Visited 1101101000: Value=-83.3171, Next City=2
# From City 9 with Visited 1101101001: Value=-69.4372, Next City=2
# From City 9 with Visited 1101101010: Value=-50.3332, Next City=7
# From City 9 with Visited 1101101011: Value=-36.3437, Next City=2
# From City 9 with Visited 1101101100: Value=-51.7616, Next City=7
# From City 9 with Visited 1101101101: Value=-43.8767, Next City=7
# From City 9 with Visited 1101101110: Value=-22.5148, Next City=7
# From City 9 with Visited 1101101111: Value=-10.7831, Next City=7
# From City 9 with Visited 1101110000: Value=-100.4883, Next City=3
# From City 9 with Visited 1101110001: Value=-75.7813, Next City=3
# From City 9 with Visited 1101110010: Value=-81.1592, Next City=2
# From City 9 with Visited 1101110011: Value=-55.2990, Next City=3
# From City 9 with Visited 1101110100: Value=-83.9101, Next City=3
# From City 9 with Visited 1101110101: Value=-60.5923, Next City=3
# From City 9 with Visited 1101110110: Value=-55.1629, Next City=3
# From City 9 with Visited 1101110111: Value=-41.7831, Next City=3
# From City 9 with Visited 1101111000: Value=-76.2341, Next City=2
# From City 9 with Visited 1101111001: Value=-53.4019, Next City=2
# From City 9 with Visited 1101111010: Value=-47.4870, Next City=2
# From City 9 with Visited 1101111011: Value=-32.9196, Next City=2
# From City 9 with Visited 1101111100: Value=-45.4051, Next City=1
# From City 9 with Visited 1101111101: Value=-37.0270, Next City=1
# From City 9 with Visited 1101111110: Value=-16.4246, Next City=7
# From City 9 with Visited 1101111111: Value=-8.0465, Next City=7
# From City 9 with Visited 1110000000: Value=-148.3141, Next City=5
# From City 9 with Visited 1110000001: Value=-123.6186, Next City=3
# From City 9 with Visited 1110000010: Value=-128.3817, Next City=2
# From City 9 with Visited 1110000011: Value=-103.2091, Next City=3
# From City 9 with Visited 1110000100: Value=-133.3630, Next City=3
# From City 9 with Visited 1110000101: Value=-108.4296, Next City=3
# From City 9 with Visited 1110000110: Value=-101.0333, Next City=3
# From City 9 with Visited 1110000111: Value=-89.0057, Next City=3
# From City 9 with Visited 1110001000: Value=-125.6871, Next City=2
# From City 9 with Visited 1110001001: Value=-101.0802, Next City=2
# From City 9 with Visited 1110001010: Value=-93.3574, Next City=2
# From City 9 with Visited 1110001011: Value=-79.8966, Next City=2
# From City 9 with Visited 1110001100: Value=-95.1589, Next City=5
# From City 9 with Visited 1110001101: Value=-86.3996, Next City=5
# From City 9 with Visited 1110001110: Value=-63.2299, Next City=5
# From City 9 with Visited 1110001111: Value=-53.9446, Next City=6
# From City 9 with Visited 1110010000: Value=-131.5311, Next City=3
# From City 9 with Visited 1110010001: Value=-97.5563, Next City=5
# From City 9 with Visited 1110010010: Value=-111.8692, Next City=5
# From City 9 with Visited 1110010011: Value=-80.8511, Next City=3
# From City 9 with Visited 1110010100: Value=-116.3421, Next City=3
# From City 9 with Visited 1110010101: Value=-83.1079, Next City=5
# From City 9 with Visited 1110010110: Value=-94.8814, Next City=3
# From City 9 with Visited 1110010111: Value=-68.6380, Next City=5
# From City 9 with Visited 1110011000: Value=-108.6661, Next City=2
# From City 9 with Visited 1110011001: Value=-84.5677, Next City=5
# From City 9 with Visited 1110011010: Value=-87.2055, Next City=2
# From City 9 with Visited 1110011011: Value=-63.3840, Next City=5
# From City 9 with Visited 1110011100: Value=-87.7751, Next City=1
# From City 9 with Visited 1110011101: Value=-69.3786, Next City=5
# From City 9 with Visited 1110011110: Value=-57.1396, Next City=5
# From City 9 with Visited 1110011111: Value=-47.9179, Next City=5
# From City 9 with Visited 1110100000: Value=-121.8366, Next City=2
# From City 9 with Visited 1110100001: Value=-96.6639, Next City=3
# From City 9 with Visited 1110100010: Value=-88.2046, Next City=2
# From City 9 with Visited 1110100011: Value=-74.2730, Next City=2
# From City 9 with Visited 1110100100: Value=-94.4882, Next City=3
# From City 9 with Visited 1110100101: Value=-82.4605, Next City=3
# From City 9 with Visited 1110100110: Value=-60.8562, Next City=3
# From City 9 with Visited 1110100111: Value=-48.8285, Next City=3
# From City 9 with Visited 1110101000: Value=-86.8123, Next City=2
# From City 9 with Visited 1110101001: Value=-73.3514, Next City=2
# From City 9 with Visited 1110101010: Value=-53.1803, Next City=2
# From City 9 with Visited 1110101011: Value=-39.7195, Next City=2
# From City 9 with Visited 1110101100: Value=-54.9905, Next City=1
# From City 9 with Visited 1110101101: Value=-47.3995, Next City=6
# From City 9 with Visited 1110101110: Value=-24.2297, Next City=6
# From City 9 with Visited 1110101111: Value=-13.7675, Next City=6
# From City 9 with Visited 1110110000: Value=-104.8156, Next City=2
# From City 9 with Visited 1110110001: Value=-80.6286, Next City=3
# From City 9 with Visited 1110110010: Value=-83.3549, Next City=2
# From City 9 with Visited 1110110011: Value=-59.4449, Next City=3
# From City 9 with Visited 1110110100: Value=-86.5616, Next City=3
# From City 9 with Visited 1110110101: Value=-65.4395, Next City=3
# From City 9 with Visited 1110110110: Value=-56.0065, Next City=3
# From City 9 with Visited 1110110111: Value=-43.9789, Next City=3
# From City 9 with Visited 1110111000: Value=-78.8857, Next City=2
# From City 9 with Visited 1110111001: Value=-56.3304, Next City=2
# From City 9 with Visited 1110111010: Value=-48.3306, Next City=2
# From City 9 with Visited 1110111011: Value=-34.8698, Next City=2
# From City 9 with Visited 1110111100: Value=-48.9003, Next City=1
# From City 9 with Visited 1110111101: Value=-39.6786, Next City=1
# From City 9 with Visited 1110111110: Value=-18.1395, Next City=6
# From City 9 with Visited 1110111111: Value=-8.9178, Next City=6
# From City 9 with Visited 1111000000: Value=-123.5592, Next City=3
# From City 9 with Visited 1111000001: Value=-91.9874, Next City=5
# From City 9 with Visited 1111000010: Value=-106.3002, Next City=5
# From City 9 with Visited 1111000011: Value=-75.2821, Next City=3
# From City 9 with Visited 1111000100: Value=-108.3702, Next City=3
# From City 9 with Visited 1111000101: Value=-76.7983, Next City=5
# From City 9 with Visited 1111000110: Value=-91.3492, Next City=3
# From City 9 with Visited 1111000111: Value=-63.0690, Next City=5
# From City 9 with Visited 1111001000: Value=-100.6943, Next City=2
# From City 9 with Visited 1111001001: Value=-76.5958, Next City=5
# From City 9 with Visited 1111001010: Value=-83.6733, Next City=2
# From City 9 with Visited 1111001011: Value=-58.5892, Next City=5
# From City 9 with Visited 1111001100: Value=-82.7926, Next City=5
# From City 9 with Visited 1111001101: Value=-61.4068, Next City=5
# From City 9 with Visited 1111001110: Value=-53.5458, Next City=5
# From City 9 with Visited 1111001111: Value=-44.3858, Next City=5
# From City 9 with Visited 1111010000: Value=-99.8998, Next City=5
# From City 9 with Visited 1111010001: Value=-65.1495, Next City=5
# From City 9 with Visited 1111010010: Value=-83.1946, Next City=3
# From City 9 with Visited 1111010011: Value=-44.3235, Next City=3
# From City 9 with Visited 1111010100: Value=-84.7108, Next City=5
# From City 9 with Visited 1111010101: Value=-45.8397, Next City=5
# From City 9 with Visited 1111010110: Value=-70.9815, Next City=5
# From City 9 with Visited 1111010111: Value=-32.1104, Next City=5
# From City 9 with Visited 1111011000: Value=-82.3498, Next City=5
# From City 9 with Visited 1111011001: Value=-51.4202, Next City=5
# From City 9 with Visited 1111011010: Value=-67.1608, Next City=5
# From City 9 with Visited 1111011011: Value=-36.2312, Next City=5
# From City 9 with Visited 1111011100: Value=-65.7716, Next City=5
# From City 9 with Visited 1111011101: Value=-31.3906, Next City=5
# From City 9 with Visited 1111011110: Value=-47.4555, Next City=5
# From City 9 with Visited 1111011111: Value=-23.6385, Next City=5
# From City 9 with Visited 1111100000: Value=-98.7001, Next City=3
# From City 9 with Visited 1111100001: Value=-74.1521, Next City=3
# From City 9 with Visited 1111100010: Value=-81.3182, Next City=2
# From City 9 with Visited 1111100011: Value=-56.1455, Next City=3
# From City 9 with Visited 1111100100: Value=-82.1219, Next City=3
# From City 9 with Visited 1111100101: Value=-58.9631, Next City=3
# From City 9 with Visited 1111100110: Value=-52.8751, Next City=3
# From City 9 with Visited 1111100111: Value=-41.9421, Next City=3
# From City 9 with Visited 1111101000: Value=-74.4460, Next City=2
# From City 9 with Visited 1111101001: Value=-51.6137, Next City=2
# From City 9 with Visited 1111101010: Value=-45.1992, Next City=2
# From City 9 with Visited 1111101011: Value=-33.6071, Next City=2
# From City 9 with Visited 1111101100: Value=-42.6242, Next City=1
# From City 9 with Visited 1111101101: Value=-35.2389, Next City=1
# From City 9 with Visited 1111101110: Value=-11.8467, Next City=4
# From City 9 with Visited 1111101111: Value=-5.7564, Next City=4
# From City 9 with Visited 1111110000: Value=-81.6791, Next City=3
# From City 9 with Visited 1111110001: Value=-52.1772, Next City=3
# From City 9 with Visited 1111110010: Value=-66.4901, Next City=3
# From City 9 with Visited 1111110011: Value=-28.9617, Next City=3
# From City 9 with Visited 1111110100: Value=-65.1009, Next City=3
# From City 9 with Visited 1111110101: Value=-36.9882, Next City=3
# From City 9 with Visited 1111110110: Value=-46.7848, Next City=3
# From City 9 with Visited 1111110111: Value=-23.2588, Next City=3
# From City 9 with Visited 1111111000: Value=-57.4250, Next City=2
# From City 9 with Visited 1111111001: Value=-34.5927, Next City=2
# From City 9 with Visited 1111111010: Value=-39.1089, Next City=2
# From City 9 with Visited 1111111011: Value=-19.4037, Next City=2
# From City 9 with Visited 1111111100: Value=-36.5340, Next City=1
# From City 9 with Visited 1111111101: Value=-18.2179, Next City=1
# From City 9 with Visited 1111111110: Value=-0.3348, Next City=0
# From City 9 with Visited 1111111111: Value=0.0000, Next City=0
